# %%
Sys.setenv(SPARK_HOME="/Users/jonathandinu/spark-1.4.1-bin-hadoop2.4/")

# %%
.libPaths(c(file.path(Sys.getenv("SPARK_HOME"), "R", "lib"), .libPaths()))

# %%
library(SparkR)
# Out:
# Attaching package: ‘SparkR’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# The following objects are masked from ‘package:base’:
#
#     intersect, sample, table

# %%
vec <- c(1,2,3)

# %%
typeof(vec)
# Out:
# [1] "double"

# %%
sc = sparkR.init(sparkPackages='com.databricks:spark-csv_2.11:1.0.3')
# Out:
# Launching java with spark-submit command /Users/jonathandinu/spark-1.4.1-bin-hadoop2.4//bin/spark-submit  --packages com.databricks:spark-csv_2.11:1.0.3 sparkr-shell /var/folders/wf/h5v75xw52g1b7wz7lwrllwrm0000gn/T//RtmpEaMhTQ/backend_portcae7556ab320

# %%
sqlContext <- sparkRSQL.init(sc)

# %%
link <- "s3n://mortar-example-data/airline-data"

# %%
flights <- read.df(sqlContext, link, source = "com.databricks.spark.csv", header='true')

# %%
head(flights)
# Out:
#   YEAR MONTH UNIQUE_CARRIER ORIGIN_AIRPORT_ID DEST_AIRPORT_ID DEP_DELAY
# 1 2012     4             AA             12478           12892     -4.00
# 2 2012     4             AA             12478           12892     -7.00
# 3 2012     4             AA             12478           12892     -6.00
# 4 2012     4             AA             12478           12892     -6.00
# 5 2012     4             AA             12478           12892     -2.00
# 6 2012     4             AA             12478           12892     -6.00
#   DEP_DELAY_NEW ARR_DELAY ARR_DELAY_NEW CANCELLED c("", "", "", "", "", "")
# 1          0.00    -21.00          0.00      0.00
# 2          0.00    -65.00          0.00      0.00
# 3          0.00    -63.00          0.00      0.00
# 4          0.00      5.00          5.00      0.00
# 5          0.00    -39.00          0.00      0.00
# 6          0.00    -34.00          0.00      0.00

# %%
printSchema(flights)
# Out:
# root
#  |-- YEAR: string (nullable = true)
#  |-- MONTH: string (nullable = true)
#  |-- UNIQUE_CARRIER: string (nullable = true)
#  |-- ORIGIN_AIRPORT_ID: string (nullable = true)
#  |-- DEST_AIRPORT_ID: string (nullable = true)
#  |-- DEP_DELAY: string (nullable = true)
#  |-- DEP_DELAY_NEW: string (nullable = true)
#  |-- ARR_DELAY: string (nullable = true)
#  |-- ARR_DELAY_NEW: string (nullable = true)
#  |-- CANCELLED: string (nullable = true)
#  |-- : string (nullable = true)

# %%
subset <- select(flights, flights$DEP_DELAY, flights$ARR_DELAY, 
                 flights$ORIGIN_AIRPORT_ID, flights$DEST_AIRPORT_ID)

# %%
persist(subset, 'MEMORY_AND_DISK')
# Out:
# DataFrame[DEP_DELAY:string, ARR_DELAY:string, ORIGIN_AIRPORT_ID:string, DEST_AIRPORT_ID:string]

# %%
head(subset)
# Out:
#   DEP_DELAY ARR_DELAY ORIGIN_AIRPORT_ID DEST_AIRPORT_ID
# 1     -4.00    -21.00             12478           12892
# 2     -7.00    -65.00             12478           12892
# 3     -6.00    -63.00             12478           12892
# 4     -6.00      5.00             12478           12892
# 5     -2.00    -39.00             12478           12892
# 6     -6.00    -34.00             12478           12892

# %%
dtypes(subset)
# Out:
# [[1]]
# [1] "DEP_DELAY" "string"
#
# [[2]]
# [1] "ARR_DELAY" "string"
#
# [[3]]
# [1] "ORIGIN_AIRPORT_ID" "string"
#
# [[4]]
# [1] "DEST_AIRPORT_ID" "string"

# %%
help(cast)
# Out:
# Column-class              package:SparkR               R Documentation
#
# n
#
# n:
#
#      The column class supports unary, binary operations on DataFrame
#      columns
#
#      Set a new name for a column
#
#      An expression that returns a substring.
#
#      Casts the column to a different data type.
#
#      Approx Count Distinct
#
#      Count Distinct
#
# e:
#
#      ## S4 method for signature 'Column'
#      alias(object, data)
#
#      ## S4 method for signature 'Column'
#      substr(x, start, stop)
#
#      ## S4 method for signature 'Column'
#      cast(x, dataType)
#
#      ## S4 method for signature 'Column'
#      approxCountDistinct(x, rsd = 0.95)
#
#      ## S4 method for signature 'Column'
#      countDistinct(x, ...)
#
#      ## S4 method for signature 'Column'
#      n_distinct(x, ...)
#
#      ## S4 method for signature 'Column'
#      n(x)
#
#      approxCountDistinct(x, ...)
#
#      asc(x)
#
#      avg(x, ...)
#
#      cast(x, dataType)
#
#      cbrt(x)
#
#      contains(x, ...)
#
#      countDistinct(x, ...)
#
#      desc(x)
#
#      endsWith(x, ...)
#
#      getField(x, ...)
#
#      getItem(x, ...)
#
#      hypot(y, x)
#
#      isNull(x)
#
#      isNotNull(x)
#
#      last(x)
#
#      like(x, ...)
#
#      lower(x)
#
#      n(x)
#
#      n_distinct(x, ...)
#
#      rint(x, ...)
#
#      rlike(x, ...)
#
#      startsWith(x, ...)
#
#      sumDistinct(x)
#
#      toDegrees(x)
#
#      toRadians(x)
#
#      upper(x)
#
# s:
#
#    start: starting position
#
#     stop: ending position
#
#       jc: reference to JVM DataFrame column
#
# e:
#
#      the approximate number of distinct items in a group.
#
#      the number of distinct items in a group.
#
# s:
#
#      ## Not run:
#
#        cast(df$age, "string")
#        cast(df$name, list(type="array", elementType="byte", containsNull = TRUE))
#      ## End(Not run)

# %%
subset$DEP_DELAY <- cast(flights$DEP_DELAY, 'double')

# %%
subset$ARR_DELAY <- cast(flights$ARR_DELAY, 'double')

# %%
head(subset)
# Out:
#   DEP_DELAY ARR_DELAY ORIGIN_AIRPORT_ID DEST_AIRPORT_ID
# 1        -4       -21             12478           12892
# 2        -7       -65             12478           12892
# 3        -6       -63             12478           12892
# 4        -6         5             12478           12892
# 5        -2       -39             12478           12892
# 6        -6       -34             12478           12892

# %%
dtypes(subset)
# Out:
# [[1]]
# [1] "DEP_DELAY" "double"
#
# [[2]]
# [1] "ARR_DELAY" "double"
#
# [[3]]
# [1] "ORIGIN_AIRPORT_ID" "string"
#
# [[4]]
# [1] "DEST_AIRPORT_ID" "string"

# %%
groupedDest <- groupBy(subset, subset$DEST_AIRPORT_ID)

# %%
groupedOrigin <- groupBy(subset, subset$ORIGIN_AIRPORT_ID)

# %%
dest_mean <- mean(groupedDest) 
origin_mean <- mean(groupedOrigin)

# %%
persist(dest_mean, "MEMORY_AND_DISK")
persist(origin_mean, "MEMORY_AND_DISK")
# Out:
# DataFrame[DEST_AIRPORT_ID:string, AVG(DEP_DELAY):double, AVG(ARR_DELAY):double]
# DataFrame[ORIGIN_AIRPORT_ID:string, AVG(DEP_DELAY):double, AVG(ARR_DELAY):double]

# %%
head(dest_mean)
# Out:
#   DEST_AIRPORT_ID AVG(DEP_DELAY) AVG(ARR_DELAY)
# 1           13277       9.154730       4.218445
# 2           10154      11.558360       5.574132
# 3           11540       8.811215       5.393523
# 4           10155       6.097440       1.539289
# 5           12884      14.577281      12.301025
# 6           12389       8.580357      -2.117117

# %%
head(arrange(dest_mean, dest_mean$'AVG(ARR_DELAY)'))
# Out:
#   DEST_AIRPORT_ID AVG(DEP_DELAY) AVG(ARR_DELAY)
# 1           12343    -12.7019231     -17.413462
# 2           12888     -0.9433962      -9.288462
# 3           11415      5.1877023      -7.711974
# 4           10466     -0.2500000      -7.437500
# 5           12335      0.0100000      -6.040000
# 6           10158      1.0958904      -5.625000

# %%
head(arrange(dest_mean, desc(dest_mean$'AVG(ARR_DELAY)')))
# Out:
#   DEST_AIRPORT_ID AVG(DEP_DELAY) AVG(ARR_DELAY)
# 1           10930       30.08428       27.36458
# 2           13424       23.66904       23.38878
# 3           14487       23.61354       22.18760
# 4           13459       20.88760       20.84884
# 5           10157       23.72505       20.40944
# 6           13964       21.90948       16.91349

# %%
dest_mean <- withColumnRenamed(dest_mean, 'AVG(ARR_DELAY)', 'Delay (min)')

# %%
head(dest_mean)
# Out:
#   DEST_AIRPORT_ID AVG(DEP_DELAY) Delay (min)
# 1           13277       9.154730    4.218445
# 2           10154      11.558360    5.574132
# 3           11540       8.811215    5.393523
# 4           10155       6.097440    1.539289
# 5           12884      14.577281   12.301025
# 6           12389       8.580357   -2.117117

# %%
arrange(dest_mean, desc(dest_mean$'Delay (min)'))
# Out:
# DataFrame[DEST_AIRPORT_ID:string, AVG(DEP_DELAY):double, Delay (min):double]

# %% [markdown]
# ## Big Data... Small Learning

# %%
# install.packages("ggplot2")
library(ggplot2)

# %%
local_df <- collect(dest_mean)

# %%
ggplot(data=local_df, aes(x='Delay (min)')) + geom_histogram(aes(fill=..count..)) + ggtitle("Average Flight Delay")
# Out:
# Error in grid.Call.graphics(L_raster, x$raster, x$x, x$y, x$width, x$height, : Empty raster

# %%
# use Spark CSV to load data
flights <- read.df(sqlContext, link, source = "com.databricks.spark.csv", header='true')

# subset columns needed
subset <- select(flights, flights$DEP_DELAY, flights$ARR_DELAY, 
                 flights$ORIGIN_AIRPORT_ID, flights$DEST_AIRPORT_ID)

# cast delay columns to double type
subset$DEP_DELAY <- cast(flights$DEP_DELAY, 'double')
subset$ARR_DELAY <- cast(flights$ARR_DELAY, 'double')

# group by airport and compute mean
groupedDest <- groupBy(subset, subset$DEST_AIRPORT_ID)
groupedOrigin <- groupBy(subset, subset$ORIGIN_AIRPORT_ID)

dest_mean <- mean(groupedDest) 
origin_mean <- mean(groupedOrigin) 

# convert SparkR dataframe to R dataframe
dest_mean <- withColumnRenamed(dest_mean, 'AVG(ARR_DELAY)', 'avg_arr_delay')
local_df <- collect(dest_mean)

# visualize with ggplot2
ggplot(data=local_df, aes(local_df$avg_arr_delay)) + geom_histogram(aes(fill=..count..))
# Out:
# stat_bin: binwidth defaulted to range/30. Use 'binwidth = x' to adjust this.
# plot without title
